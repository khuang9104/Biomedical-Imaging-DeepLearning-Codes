# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Sun Nov  6 10:08:28 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   29C    P0    44W / 400W |      0MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
! pip -qq install git+https://github.com/qubvel/segmentation_models.pytorch
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 58 kB 3.5 MB/s
#      |████████████████████████████████| 376 kB 10.3 MB/s
#   Building wheel for segmentation-models-pytorch (PEP 517) ... done
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Building wheel for pretrainedmodels (setup.py) ... done

# %%
import segmentation_models_pytorch as smp
from segmentation_models_pytorch.utils import metrics
import os
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
from google.colab import drive
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import time
import albumentations as A
import torch.nn.functional as F
import pandas as pd
import nibabel as nib
from tqdm import tqdm

# %%
!7za x TrainSet.zip
# Out:
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,12 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (50657),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 3693478666 bytes (3523 MiB)
#
# Extracting archive: TrainSet.zip
# --
# Path = TrainSet.zip
# Type = zip
# Physical Size = 3693478666
#
# Everything is Ok
#
# Folders: 300
# Files: 1500
# Size:       3765196897
# Compressed: 3693478666

# %%
!7za x TestSet.zip
# Out:
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,12 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (50657),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 900960358 bytes (860 MiB)
#
# Extracting archive: TestSet.zip
# --
# Path = TestSet.zip
# Type = zip
# Physical Size = 900960358
#
# Everything is Ok
#
# Folders: 74
# Files: 370
# Size:       918788812
# Compressed: 900960358

# %%
DataPath_train = '/content/TrainSet'

# %%
subject_train = []
subject_dir_train = []
image_T1_train = []
image_T1c_train = []
image_T2_train = []
image_Flair_train = []
image_Mask_train = []
image_Path_train = {
              'Segmentation': [],    
              'T1': [],
              'T1c': [],
              'T2': [],
              'FLAIR': []
          }

def findFiles(file_path):
    files = os.listdir(file_path) 
    for file_name in files:
        npath = file_path + '/' + file_name                                
        if "tumor_segmentation" in file_name: 
          subject_train.append(str(file_name).split("_")[0])
          image_Mask_train.append(file_name)
          image_T1_train.append(file_name.replace("tumor_segmentation","T1"))   
          image_T1c_train.append(file_name.replace("tumor_segmentation","T1c")) 
          image_T2_train.append(file_name.replace("tumor_segmentation","T2")) 
          image_Flair_train.append(file_name.replace("tumor_segmentation","FLAIR"))
          image_Path_train['Segmentation'].append(npath)
          image_Path_train['T1'].append(npath.replace("tumor_segmentation","T1"))   
          image_Path_train['T1c'].append(npath.replace("tumor_segmentation","T1c")) 
          image_Path_train['T2'].append(npath.replace("tumor_segmentation","T2")) 
          image_Path_train['FLAIR'].append(npath.replace("tumor_segmentation","FLAIR"))    
        if os.path.isdir(npath):   
            if file_name[0] == '.':
                pass
            else:
                findFiles(npath)

findFiles(DataPath_train)
# Out:
# 0

# %%
df_summary_train = pd.DataFrame({'subjects':subject_train, 'T1':image_T1_train, 'T1c':image_T1c_train, 'T2':image_T2_train, 'FLAIR':image_Flair_train, 'masks':image_Mask_train})
df_summary_train.head(10)
# Out:
#          subjects                        T1                        T1c  \
# 0  UCSF-PDGM-0416  UCSF-PDGM-0416_T1.nii.gz  UCSF-PDGM-0416_T1c.nii.gz
# 1  UCSF-PDGM-0010  UCSF-PDGM-0010_T1.nii.gz  UCSF-PDGM-0010_T1c.nii.gz
# 2  UCSF-PDGM-0066  UCSF-PDGM-0066_T1.nii.gz  UCSF-PDGM-0066_T1c.nii.gz
# 3  UCSF-PDGM-0533  UCSF-PDGM-0533_T1.nii.gz  UCSF-PDGM-0533_T1c.nii.gz
# 4  UCSF-PDGM-0362  UCSF-PDGM-0362_T1.nii.gz  UCSF-PDGM-0362_T1c.nii.gz
# 5  UCSF-PDGM-0410  UCSF-PDGM-0410_T1.nii.gz  UCSF-PDGM-0410_T1c.nii.gz
# 6  UCSF-PDGM-0306  UCSF-PDGM-0306_T1.nii.gz  UCSF-PDGM-0306_T1c.nii.gz
# 7  UCSF-PDGM-0481  UCSF-PDGM-0481_T1.nii.gz  UCSF-PDGM-0481_T1c.nii.gz
# 8  UCSF-PDGM-0510  UCSF-PDGM-0510_T1.nii.gz  UCSF-PDGM-0510_T1c.nii.gz
# 9  UCSF-PDGM-0313  UCSF-PDGM-0313_T1.nii.gz  UCSF-PDGM-0313_T1c.nii.gz
#
#                          T2                        FLAIR  \
# 0  UCSF-PDGM-0416_T2.nii.gz  UCSF-PDGM-0416_FLAIR.nii.gz
# 1  UCSF-PDGM-0010_T2.nii.gz  UCSF-PDGM-0010_FLAIR.nii.gz
# 2  UCSF-PDGM-0066_T2.nii.gz  UCSF-PDGM-0066_FLAIR.nii.gz
# 3  UCSF-PDGM-0533_T2.nii.gz  UCSF-PDGM-0533_FLAIR.nii.gz
# 4  UCSF-PDGM-0362_T2.nii.gz  UCSF-PDGM-0362_FLAIR.nii.gz
# 5  UCSF-PDGM-0410_T2.nii.gz  UCSF-PDGM-0410_FLAIR.nii.gz
# 6  UCSF-PDGM-0306_T2.nii.gz  UCSF-PDGM-0306_FLAIR.nii.gz
# 7  UCSF-PDGM-0481_T2.nii.gz  UCSF-PDGM-0481_FLAIR.nii.gz
# 8  UCSF-PDGM-0510_T2.nii.gz  UCSF-PDGM-0510_FLAIR.nii.gz
# 9  UCSF-PDGM-0313_T2.nii.gz  UCSF-PDGM-0313_FLAIR.nii.gz
#
#                                       masks
# 0  UCSF-PDGM-0416_tumor_segmentation.nii.gz
# 1  UCSF-PDGM-0010_tumor_segmentation.nii.gz
# 2  UCSF-PDGM-0066_tumor_segmentation.nii.gz
# 3  UCSF-PDGM-0533_tumor_segmentation.nii.gz
# 4  UCSF-PDGM-0362_tumor_segmentation.nii.gz
# 5  UCSF-PDGM-0410_tumor_segmentation.nii.gz
# 6  UCSF-PDGM-0306_tumor_segmentation.nii.gz
# 7  UCSF-PDGM-0481_tumor_segmentation.nii.gz
# 8  UCSF-PDGM-0510_tumor_segmentation.nii.gz
# 9  UCSF-PDGM-0313_tumor_segmentation.nii.gz

# %%
len(df_summary_train)
# Out:
# 300

# %%
DataPath_test = '/content/TestSet'

# %%
subject_test = []
subject_dir_test = []
image_T1_test = []
image_T1c_test = []
image_T2_test = []
image_Flair_test = []
image_Mask_test = []
image_Path_test = {
              'Segmentation': [],    
              'T1': [],
              'T1c': [],
              'T2': [],
              'FLAIR': []
          }
def findFiles(file_path):
    files = os.listdir(file_path) 
    for file_name in files:
        npath = file_path + '/' + file_name                                 
        if "tumor_segmentation" in file_name:
          subject_test.append(str(file_name).split("_")[0])
          subject_dir_test = file_path
          image_Mask_test.append(file_name)
          image_T1_test.append(file_name.replace("tumor_segmentation","T1"))   
          image_T1c_test.append(file_name.replace("tumor_segmentation","T1c")) 
          image_T2_test.append(file_name.replace("tumor_segmentation","T2")) 
          image_Flair_test.append(file_name.replace("tumor_segmentation","FLAIR"))
          image_Path_test['Segmentation'].append(npath)
          image_Path_test['T1'].append(npath.replace("tumor_segmentation","T1"))   
          image_Path_test['T1c'].append(npath.replace("tumor_segmentation","T1c")) 
          image_Path_test['T2'].append(npath.replace("tumor_segmentation","T2")) 
          image_Path_test['FLAIR'].append(npath.replace("tumor_segmentation","FLAIR"))    
        if os.path.isdir(npath):   
            if file_name[0] == '.':
                pass
            else:
                findFiles(npath) 
     
findFiles(DataPath_test)

# %%
df_summary_test = pd.DataFrame({'subjects':subject_test, 'T1':image_T1_test, 'T1c':image_T1c_test, 'T2':image_T2_test, 'FLAIR':image_Flair_test, 'masks':image_Mask_test})
df_summary_test.head(10)
# Out:
#          subjects                        T1                        T1c  \
# 0  UCSF-PDGM-0406  UCSF-PDGM-0406_T1.nii.gz  UCSF-PDGM-0406_T1c.nii.gz
# 1  UCSF-PDGM-0291  UCSF-PDGM-0291_T1.nii.gz  UCSF-PDGM-0291_T1c.nii.gz
# 2  UCSF-PDGM-0383  UCSF-PDGM-0383_T1.nii.gz  UCSF-PDGM-0383_T1c.nii.gz
# 3  UCSF-PDGM-0064  UCSF-PDGM-0064_T1.nii.gz  UCSF-PDGM-0064_T1c.nii.gz
# 4  UCSF-PDGM-0537  UCSF-PDGM-0537_T1.nii.gz  UCSF-PDGM-0537_T1c.nii.gz
# 5  UCSF-PDGM-0113  UCSF-PDGM-0113_T1.nii.gz  UCSF-PDGM-0113_T1c.nii.gz
# 6  UCSF-PDGM-0142  UCSF-PDGM-0142_T1.nii.gz  UCSF-PDGM-0142_T1c.nii.gz
# 7  UCSF-PDGM-0130  UCSF-PDGM-0130_T1.nii.gz  UCSF-PDGM-0130_T1c.nii.gz
# 8  UCSF-PDGM-0181  UCSF-PDGM-0181_T1.nii.gz  UCSF-PDGM-0181_T1c.nii.gz
# 9  UCSF-PDGM-0479  UCSF-PDGM-0479_T1.nii.gz  UCSF-PDGM-0479_T1c.nii.gz
#
#                          T2                        FLAIR  \
# 0  UCSF-PDGM-0406_T2.nii.gz  UCSF-PDGM-0406_FLAIR.nii.gz
# 1  UCSF-PDGM-0291_T2.nii.gz  UCSF-PDGM-0291_FLAIR.nii.gz
# 2  UCSF-PDGM-0383_T2.nii.gz  UCSF-PDGM-0383_FLAIR.nii.gz
# 3  UCSF-PDGM-0064_T2.nii.gz  UCSF-PDGM-0064_FLAIR.nii.gz
# 4  UCSF-PDGM-0537_T2.nii.gz  UCSF-PDGM-0537_FLAIR.nii.gz
# 5  UCSF-PDGM-0113_T2.nii.gz  UCSF-PDGM-0113_FLAIR.nii.gz
# 6  UCSF-PDGM-0142_T2.nii.gz  UCSF-PDGM-0142_FLAIR.nii.gz
# 7  UCSF-PDGM-0130_T2.nii.gz  UCSF-PDGM-0130_FLAIR.nii.gz
# 8  UCSF-PDGM-0181_T2.nii.gz  UCSF-PDGM-0181_FLAIR.nii.gz
# 9  UCSF-PDGM-0479_T2.nii.gz  UCSF-PDGM-0479_FLAIR.nii.gz
#
#                                       masks
# 0  UCSF-PDGM-0406_tumor_segmentation.nii.gz
# 1  UCSF-PDGM-0291_tumor_segmentation.nii.gz
# 2  UCSF-PDGM-0383_tumor_segmentation.nii.gz
# 3  UCSF-PDGM-0064_tumor_segmentation.nii.gz
# 4  UCSF-PDGM-0537_tumor_segmentation.nii.gz
# 5  UCSF-PDGM-0113_tumor_segmentation.nii.gz
# 6  UCSF-PDGM-0142_tumor_segmentation.nii.gz
# 7  UCSF-PDGM-0130_tumor_segmentation.nii.gz
# 8  UCSF-PDGM-0181_tumor_segmentation.nii.gz
# 9  UCSF-PDGM-0479_tumor_segmentation.nii.gz

# %%
len(df_summary_test)
# Out:
# 74

# %%
def loadimg(imgpath):
    return nib.load(imgpath).get_fdata()

def ccentre(imgslice, cropx, cropy):
    y, x = imgslice.shape
    startx = x // 2 - (cropx // 2)
    starty = y // 2 - (cropy // 2)    
    return imgslice[starty:starty + cropy, startx:startx + cropx]

def normalizer(imgslice):
    return (imgslice - imgslice.mean()) / imgslice.std()

# %%
! mkdir DatasetTrain
! mkdir DatasetTrain/T1
! mkdir DatasetTrain/T1c
! mkdir DatasetTrain/T2
! mkdir DatasetTrain/FLAIR
! mkdir DatasetTrain/Segmentation

# %%
! mkdir DatasetTest
! mkdir DatasetTest/T1
! mkdir DatasetTest/T1c
! mkdir DatasetTest/T2
! mkdir DatasetTest/FLAIR
! mkdir DatasetTest/Segmentation

# %%
numOfImgsSaved_train = 0
imgs_train = {}
image_slice_train = {}

for i in (range(len(image_Path_train['Segmentation']))):
    for name in image_Path_train:
        imgs_train[name] = loadimg(image_Path_train[name][i])
    
    for j in range(155):
        for name in imgs_train:
            image_slice_train[name] = imgs_train[name][:, :, j]
            image_slice_train[name] = ccentre(image_slice_train[name], 224, 224)
        if image_slice_train['Segmentation'].max() > 0:
            for name in ['T1','T2','T1c','FLAIR']:
              image_slice_train[name] = normalizer(image_slice_train[name])
            for name in ['Segmentation']:
              image_slice_train[name] = np.rint(image_slice_train[name])
            for name in image_slice_train:
              np.save(f'./DatasetTrain/{name}/image_{numOfImgsSaved_train}.npy', image_slice_train[name])
            numOfImgsSaved_train += 1

print(numOfImgsSaved_train)
# Out:
# 19057

# %%
numOfImgsSaved_test = 0
imgs_test = {}
image_slice_test = {}

for i in (range(len(image_Path_test['Segmentation']))):
    for name in image_Path_test:
        imgs_test[name] = loadimg(image_Path_test[name][i])
    
    for j in range(155):
        for name in imgs_test:
            image_slice_test[name] = imgs_test[name][:, :, j]
            image_slice_test[name] = ccentre(image_slice_test[name], 224, 224)
        if image_slice_test['Segmentation'].max() > 0:
            for name in ['T1','T2','T1c','FLAIR']:
              image_slice_test[name] = normalizer(image_slice_test[name])
            for name in ['Segmentation']:
              image_slice_test[name] = np.rint(image_slice_test[name])
            for name in image_slice_test:
              np.save(f'./DatasetTest/{name}/image_{numOfImgsSaved_test}.npy', image_slice_test[name])
            numOfImgsSaved_test += 1

print(numOfImgsSaved_test)
# Out:
# 4820

# %%
index = 25

fig = plt.figure(figsize = (24, 15))
plt.subplot(1, 5, 1)
plt.imshow(np.load('DatasetTrain/FLAIR/image_' + str(index) + '.npy'), cmap = 'bone')
plt.title('FLAIR')

plt.subplot(1, 5, 2)
plt.imshow(np.load('DatasetTrain/T1/image_' + str(index) + '.npy'), cmap = 'bone')
plt.title('T1')

plt.subplot(1, 5, 3)
plt.imshow(np.load('DatasetTrain/Segmentation/image_' + str(index) + '.npy'), cmap = 'bone')
plt.title('Segmentation Mask')

plt.subplot(1, 5, 4)
plt.imshow(np.load('DatasetTrain/T1c/image_' + str(index) + '.npy'), cmap = 'bone')
plt.title('T1c')

plt.subplot(1, 5, 5)
plt.imshow(np.load('DatasetTrain/T2/image_' + str(index) + '.npy'), cmap = 'bone')
plt.title('T2')
# Out:
# Text(0.5, 1.0, 'T2')

# %%
index = 25

fig = plt.figure(figsize = (24, 15))
plt.subplot(1, 5, 1)
plt.imshow(np.load('DatasetTrain/FLAIR/image_' + str(index) + '.npy'), cmap = 'bone')
plt.title('FLAIR')

plt.subplot(1, 5, 2)
plt.imshow(np.load('DatasetTrain/FLAIR/image_' + str(index) + '.npy'), cmap = 'bone')
plt.imshow(np.load('DatasetTrain/T1/image_' + str(index) + '.npy'), alpha = 0.5, cmap = 'nipy_spectral')
plt.title('FLAIR (T1 Mask)')

plt.subplot(1, 5, 3)
plt.imshow(np.load('DatasetTrain/FLAIR/image_' + str(index) + '.npy'), cmap = 'bone')
plt.imshow(np.load('DatasetTrain/Segmentation/image_' + str(index) + '.npy'), alpha = 0.5, cmap = 'nipy_spectral')
plt.title('FLAIR (Segmentation mask)')

plt.subplot(1, 5, 4)
plt.imshow(np.load('DatasetTrain/FLAIR/image_' + str(index) + '.npy'), cmap = 'bone')
plt.imshow(np.load('DatasetTrain/T1c/image_' + str(index) + '.npy'), alpha = 0.5, cmap = 'nipy_spectral')
plt.title('FLAIR (T1c Mask)')

plt.subplot(1, 5, 5)
plt.imshow(np.load('DatasetTrain/FLAIR/image_' + str(index) + '.npy'), cmap = 'bone')
plt.imshow(np.load('DatasetTrain/T2/image_' + str(index) + '.npy'), alpha = 0.5, cmap = 'nipy_spectral')
plt.title('FLAIR (T2 Mask)')
# Out:
# Text(0.5, 1.0, 'FLAIR (T2 Mask)')

# %%
class Dataset(Dataset):

#    CLASSES = ['edema', 'tumour', 'cysy']
    
    def __init__(self, datapath, augmentation = None):
        self.augmentation = augmentation
#        self.class_values = ['edema', 'tumour', 'cysy']
        self.folderpaths = {
#                              'mask_edema': os.path.join(datapath, 'Segmentation/'),
                              'mask_cysy': os.path.join(datapath, 'Segmentation/'),
#                              'mask_tumour': os.path.join(datapath, 'Segmentation/'),
                              't1': os.path.join(datapath, 'T1/'),
                              't1c': os.path.join(datapath, 'T1c/'),
                              't2': os.path.join(datapath, 'T2/'),
                              'flair': os.path.join(datapath, 'FLAIR/')
                          }
    
    def __getitem__(self, idx):
        images = {}
        for name in self.folderpaths:
            images[name] = np.load(os.path.join(self.folderpaths[name], f'image_{idx}.npy'))

        if self.augmentation:
            images = self.augmentation(
                                        image = images['flair'],
#                                        mask_edema = images['mask_edema'],
#                                        mask_tumour = images['mask_tumour'],
                                        mask_cysy = images['mask_cysy'],
                                        t1 = images['t1'],
                                        t1c = images['t1c'],
                                        t2 = images['t2'] )
            images['flair'] = images['image']

        for name in images:
            images[name] = torch.from_numpy(images[name])

        # stacking multi ins
        images_input = torch.stack(
                                [images['t1'],
                                images['t1c'],
                                images['t2'],
                                images['flair']], dim = 0
                            )
        
        # Edema 127
        #images['mask_edema'][images['mask_edema'] == 4] = 0 # 255 = 0
        #images['mask_edema'][images['mask_edema'] == 1] = 0 # 64 = 0
        #images['mask_edema'][images['mask_edema'] == 2] = 1 # 127 = 1

        # Tumour 255
        #images['mask_tumour'][images['mask_tumour'] == 1] = 0 # 64 = 0
        #images['mask_tumour'][images['mask_tumour'] == 2] = 0 # 127 = 0
        #images['mask_tumour'][images['mask_tumour'] == 4] = 1 # 255 = 1

        # Cysy 64
        images['mask_cysy'][images['mask_cysy'] == 4] = 0 # 255 = 0
        images['mask_cysy'][images['mask_cysy'] == 2] = 0 # 127 = 0
        images['mask_cysy'][images['mask_cysy'] == 1] = 1 # 64 = 1
        
        masks_input = torch.stack([images['mask_cysy']], dim = 0)
        return images_input.float(), masks_input.float()
    
    def __len__(self):
        return len(os.listdir(self.folderpaths['mask_cysy'])) - 1

# %%
# Tune-able
augmentation = A.Compose([
    A.OneOf([
                A.ElasticTransform(alpha = 120, sigma = 120 * 0.05, alpha_affine = 120 * 0.03, p = 0.5),
                A.GridDistortion(p = 0.5),
                A.OpticalDistortion(distort_limit = 2, shift_limit = 0.5, p = 0.5)                  
            ], p = 0.8),
    A.RandomBrightnessContrast(p = 0.8)], 
    additional_targets = {'t1':'image', 't1c':'image', 't2':'image'}
                         )

train_dataset = Dataset(datapath = './DatasetTrain/', augmentation = None)

# 60%/20%/20% 
train_length = int(len(train_dataset)*0.75)
valid_length = int(len(train_dataset)*0.25)

train_dataset, valid_dataset = torch.utils.data.random_split(train_dataset, (train_length, valid_length), generator=torch.Generator().manual_seed(42))
test_dataset = Dataset(datapath = './DatasetTest/', augmentation = None)

# %%
len(train_dataset),len(valid_dataset),len(test_dataset)

# %%
train_loader = DataLoader(train_dataset,
                      batch_size=128,
                      num_workers=12,
                      shuffle=False)

valid_loader = DataLoader(valid_dataset,
                      batch_size=128,
                      num_workers=12,
                      shuffle=False)

test_loader = DataLoader(test_dataset,
                      batch_size=128,
                      num_workers=12,
                      shuffle=False)

# %%
index = 5047

image, gt_mask = train_dataset[index]

plt.figure(figsize = (16, 16))

plt.subplot(4, 4, 1)
plt.imshow(image[0,:,:],cmap='gray')
plt.title('Input Image T1')
plt.subplot(4, 4, 2)
plt.imshow(image[1,:,:],cmap='gray')
plt.title('Input Image T1c')
plt.subplot(4, 4, 3)
plt.imshow(image[2,:,:],cmap='gray')
plt.title('Input Image T2')
plt.subplot(4, 4, 4)
plt.imshow(image[3,:,:],cmap='gray')
plt.title('Input Image FLAIR')

plt.subplot(4, 4, 5)
plt.imshow(gt_mask[0,:,:],cmap='gray')
plt.title('GTSeg-Edema')
#plt.subplot(4, 4, 6)
#plt.imshow(gt_mask[1,:,:],cmap='gray')
#plt.title('GTSeg-Tumour')
#plt.subplot(4, 4, 7)
#plt.imshow(gt_mask[2,:,:],cmap='gray')
#plt.title('GTSeg-Cysy/Necrosis')
plt.subplot(4, 4, 6)
plt.imshow(np.load('DatasetTrain/Segmentation/image_' + str(index) + '.npy'), cmap = 'gray')
plt.title('GTMask')
# Out:
# Text(0.5, 1.0, 'GTMask')

# %%
# importing model
MODEL = smp.Unet(encoder_name='resnet50',
                 encoder_depth=5,
                 encoder_weights='imagenet',
                 decoder_channels=[1024,512,256,128,64],
                 in_channels=4,
                 classes=1,
                 activation=None)

# %%
backgroundchannel = [0]

DICE_LOSS = smp.utils.losses.DiceLoss(activation = 'sigmoid')  

OPTIMIZER = torch.optim.Adam([ 
                                dict(params=MODEL.parameters(), lr = 0.0001),
                             ])
METRICS = [
              metrics.IoU(threshold = 0.5,ignore_channels = backgroundchannel, activation = 'sigmoid'),
              metrics.Fscore(ignore_channels = backgroundchannel, activation = 'sigmoid'),
          ]

# %%
train_epoch = smp.utils.train.TrainEpoch(
                                            model = MODEL,
                                            loss = DICE_LOSS,
                                            metrics = [],
                                            optimizer = OPTIMIZER,
                                            device = "cuda",
                                            verbose = True
                                        )
valid_epoch = smp.utils.train.ValidEpoch(
                                            model = MODEL,
                                            loss = DICE_LOSS,
                                            metrics = METRICS,
                                            device = "cuda",
                                            verbose = True
                                        )

max_dice_score = 1
stats = {
          'train_loss' : [],
          'valid_loss' : [],
          'fscore' : [],
          'iou_score' : []
        }

for i in range(200):
  print(f'\n --- Epoch {i} --- ')
  train_logs = train_epoch.run(train_loader)
  valid_logs = valid_epoch.run(valid_loader)
  
  if max_dice_score > valid_logs['dice_loss']:
      max_dice_score = valid_logs['dice_loss']
      torch.save(MODEL.state_dict(), f'./model.pth')
      print('model saved!')
  
  # loss statistics
  stats['train_loss'].append(train_logs['dice_loss'])
  stats['valid_loss'].append(valid_logs['dice_loss'])

  # metric statistics
  stats['fscore'].append(valid_logs['fscore'])
  stats['iou_score'].append(valid_logs['iou_score'])
  np.save(f'./model.npy', stats)
# Out:
#  --- Epoch 0 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.8754]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.44it/s, dice_loss - 0.6849, iou_score - 1.0, fscore - 1.0]
# model saved!
#
#  --- Epoch 1 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.3342]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.45it/s, dice_loss - 0.1411, iou_score - 1.0, fscore - 1.0]
# model saved!
#
#  --- Epoch 2 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.1012]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.42it/s, dice_loss - 0.08043, iou_score - 1.0, fscore - 1.0]
# model saved!
#
#  --- Epoch 3 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.07056]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.41it/s, dice_loss - 0.06678, iou_score - 1.0, fscore - 1.0]
# model saved!
#
#  --- Epoch 4 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.06038]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.42it/s, dice_loss - 0.05838, iou_score - 1.0, fscore - 1.0]
# model saved!
#
#  --- Epoch 5 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.0551]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.41it/s, dice_loss - 0.05504, iou_score - 1.0, fscore - 1.0]
# model saved!
#
#  --- Epoch 6 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.05458]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.43it/s, dice_loss - 0.05035, iou_score - 1.0, fscore - 1.0]
# model saved!
#
#  --- Epoch 7 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.04781]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.42it/s, dice_loss - 0.04805, iou_score - 1.0, fscore - 1.0]
# model saved!
#
#  --- Epoch 8 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.04315]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.41it/s, dice_loss - 0.04643, iou_score - 1.0, fscore - 1.0]
# model saved!
#
#  --- Epoch 9 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.04071]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.42it/s, dice_loss - 0.04472, iou_score - 1.0, fscore - 1.0]
# model saved!
#
#  --- Epoch 10 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.03874]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.44it/s, dice_loss - 0.04693, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 11 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.03794]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.43it/s, dice_loss - 0.046, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 12 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.03826]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.44it/s, dice_loss - 0.04401, iou_score - 1.0, fscore - 1.0]
# model saved!
#
#  --- Epoch 13 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.03746]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.43it/s, dice_loss - 0.04184, iou_score - 1.0, fscore - 1.0]
# model saved!
#
#  --- Epoch 14 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.03737]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.42it/s, dice_loss - 0.04312, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 15 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.03823]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.40it/s, dice_loss - 0.04133, iou_score - 1.0, fscore - 1.0]
# model saved!
#
#  --- Epoch 16 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.03545]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.39it/s, dice_loss - 0.04426, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 17 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.03324]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.44it/s, dice_loss - 0.04259, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 18 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.03277]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.39it/s, dice_loss - 0.04258, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 19 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.03264]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.44it/s, dice_loss - 0.03983, iou_score - 1.0, fscore - 1.0]
# model saved!
#
#  --- Epoch 20 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.0311]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.40it/s, dice_loss - 0.03895, iou_score - 1.0, fscore - 1.0]
# model saved!
#
#  --- Epoch 21 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.0294]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.40it/s, dice_loss - 0.03958, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 22 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.02926]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.38it/s, dice_loss - 0.04039, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 23 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.02913]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.40it/s, dice_loss - 0.0377, iou_score - 1.0, fscore - 1.0]
# model saved!
#
#  --- Epoch 24 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.02725]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.40it/s, dice_loss - 0.037, iou_score - 1.0, fscore - 1.0]
# model saved!
#
#  --- Epoch 25 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.02775]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.44it/s, dice_loss - 0.03805, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 26 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.02769]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.43it/s, dice_loss - 0.03771, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 27 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.02678]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.43it/s, dice_loss - 0.03887, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 28 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.02514]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.42it/s, dice_loss - 0.03748, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 29 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.02371]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.42it/s, dice_loss - 0.03906, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 30 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.02367]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.37it/s, dice_loss - 0.03742, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 31 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.02357]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.40it/s, dice_loss - 0.03771, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 32 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.02396]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.44it/s, dice_loss - 0.03665, iou_score - 1.0, fscore - 1.0]
# model saved!
#
#  --- Epoch 33 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.02322]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.41it/s, dice_loss - 0.0377, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 34 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.02389]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.43it/s, dice_loss - 0.03953, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 35 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.02352]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.42it/s, dice_loss - 0.04073, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 36 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.02243]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.39it/s, dice_loss - 0.03771, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 37 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.02061]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.41it/s, dice_loss - 0.03749, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 38 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.01918]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.38it/s, dice_loss - 0.03724, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 39 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.01861]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.43it/s, dice_loss - 0.03796, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 40 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.01864]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.41it/s, dice_loss - 0.03615, iou_score - 1.0, fscore - 1.0]
# model saved!
#
#  --- Epoch 41 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.01825]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.39it/s, dice_loss - 0.03911, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 42 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.01818]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.43it/s, dice_loss - 0.03665, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 43 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.01708]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.44it/s, dice_loss - 0.03697, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 44 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.01644]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.44it/s, dice_loss - 0.03648, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 45 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.01614]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.39it/s, dice_loss - 0.04079, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 46 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.01601]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.44it/s, dice_loss - 0.03851, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 47 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.01588]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.41it/s, dice_loss - 0.03926, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 48 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.01603]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.42it/s, dice_loss - 0.03866, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 49 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.01601]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.40it/s, dice_loss - 0.03813, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 50 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.01586]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.40it/s, dice_loss - 0.03927, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 51 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.01598]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.42it/s, dice_loss - 0.04198, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 52 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.01564]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.44it/s, dice_loss - 0.03737, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 53 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.01481]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.35it/s, dice_loss - 0.03652, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 54 ---
# train: 100%|██████████| 112/112 [01:26<00:00,  1.29it/s, dice_loss - 0.01434]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.44it/s, dice_loss - 0.0372, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 55 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.29it/s, dice_loss - 0.01389]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.41it/s, dice_loss - 0.03604, iou_score - 1.0, fscore - 1.0]
# model saved!
#
#  --- Epoch 56 ---
# train: 100%|██████████| 112/112 [01:27<00:00,  1.28it/s, dice_loss - 0.01424]
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.42it/s, dice_loss - 0.03658, iou_score - 1.0, fscore - 1.0]
#
#  --- Epoch 57 ---
# train:   5%|▌         | 6/112 [00:07<02:09,  1.22s/it, dice_loss - 0.01265]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-123-84b7d2bbad60> in <module>
#      25 for i in range(200):
#      26   print(f'\n --- Epoch {i} --- ')
# ---> 27   train_logs = train_epoch.run(train_loader)
#      28   valid_logs = valid_epoch.run(valid_loader)
#      29
#
# /usr/local/lib/python3.7/dist-packages/segmentation_models_pytorch/utils/train.py in run(self, dataloader)
#      49             for x, y in iterator:
#      50                 x, y = x.to(self.device), y.to(self.device)
# ---> 51                 loss, y_pred = self.batch_update(x, y)
#      52
#      53                 # update loss logs
#
# /usr/local/lib/python3.7/dist-packages/segmentation_models_pytorch/utils/train.py in batch_update(self, x, y)
#      91         loss = self.loss(prediction, y)
#      92         loss.backward()
# ---> 93         self.optimizer.step()
#      94         return loss, prediction
#      95
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     111                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#     112                 with torch.autograd.profiler.record_function(profile_name):
# --> 113                     return func(*args, **kwargs)
#     114             return wrapper
#     115
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/adam.py in step(self, closure)
#     169                  maximize=group['maximize'],
#     170                  foreach=group['foreach'],
# --> 171                  capturable=group['capturable'])
#     172
#     173         return loss
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/adam.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     224          eps=eps,
#     225          maximize=maximize,
# --> 226          capturable=capturable)
#     227
#     228
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/adam.py in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable)
#     305                 denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     306
# --> 307             param.addcdiv_(exp_avg, denom, value=-step_size)
#     308
#     309
#
# KeyboardInterrupt:

# %%
MODEL.load_state_dict(torch.load('/content/drive/MyDrive/4C1C-cysy/55ep/model.pth'))
# Out:
# <All keys matched successfully>

# %%
test_epoch = smp.utils.train.ValidEpoch(
    model=MODEL,
    loss=DICE_LOSS,
    metrics=METRICS,
    device="cuda",
)
logs = test_epoch.run(test_loader)
# Out:
# valid: 100%|██████████| 38/38 [00:11<00:00,  3.38it/s, dice_loss - 0.1138, iou_score - 1.0, fscore - 1.0]

# %%
index = 2544

image, gt_mask = test_dataset[index]
x_tensor = torch.from_numpy(np.asarray(image)).to("cuda").unsqueeze(0)
predict_mask = MODEL.predict(x_tensor)
predict_mask = (predict_mask.squeeze().cpu().numpy().round())

predict_mask_B = np.zeros([224,224])
for i in range(224):
  for j in range(224):
    if predict_mask[i,j]>=0.5:
      predict_mask_B[i,j] = 1
    else :
      predict_mask_B[i,j] = 0

plt.figure(figsize = (16, 16))

plt.subplot(4, 4, 1)
plt.imshow(image[0,:,:],cmap='gray')
plt.title('Input Image T1')
plt.subplot(4, 4, 2)
plt.imshow(image[1,:,:],cmap='gray')
plt.title('Input Image T1c')
plt.subplot(4, 4, 3)
plt.imshow(image[2,:,:],cmap='gray')
plt.title('Input Image T2')
plt.subplot(4, 4, 4)
plt.imshow(image[3,:,:],cmap='gray')
plt.title('Input Image FLAIR')

plt.subplot(4, 4, 5)
plt.imshow(np.load('DatasetTest/Segmentation/image_' + str(index) + '.npy'), cmap = 'gray')
plt.title('Segmentation Mask')
plt.subplot(4, 4, 6)
plt.imshow(gt_mask[0,:,:],cmap='gray')
plt.title('GTSeg-Edema')
plt.subplot(4, 4, 7)
plt.imshow(predict_mask[:,:], cmap = 'gray')
plt.title('Prediction-1')
plt.subplot(4, 4, 8)
plt.imshow(predict_mask_B, cmap = 'gray')
plt.title('Prediction-1')
# Out:
# Text(0.5, 1.0, 'Prediction-1')
